# %% [markdown]
# Please note that this assignment has been copied from the famous **Titanic: Machine Learning from Disaster** on [Kaggle](https://www.kaggle.com/). Thus, we recommend you to visit the competition page on https://www.kaggle.com/c/titanic. After visiting this page, you need to find the **Notebooks** tab, where you should get the solutions.
